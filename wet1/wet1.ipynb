# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import datasets
import swiss_roll_dr
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [10, 5]

# %%
swiss = datasets.generate_swiss_roll()

# %%
swiss_roll_dr.swiss_pca_and_plot(swiss[0], swiss[1])

# %%
swiss_roll_dr.swiss_manifold_and_plot(swiss[0], swiss[1])

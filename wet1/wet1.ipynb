# %%
# %load_ext autoreload
# %autoreload 2

# %%
import datasets
import dr_and_plot
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [20, 10]

# %%
dr_and_plot.do_swiss_roll()

# %%
import datasets
swiss, colors = datasets.generate_swiss_roll()

# %%
from sklearn.neighbors import NearestNeighbors
import pca_functions
import manifold_functions
import numpy as np

# %%
pca_reduced = pca_functions.pca(swiss)

# %%
import euclidean_distances_functions

# %%
f, s, rd, d, nn_idx = euclidean_distances_functions.find_far_pair(swiss, pca_reduced)

# %%
f, s, rd, d, nn_idx[f]
# Out:
# (0,
#  1,
#  0.6668366187459082,
#  2.120910648675016,
#  array([1037,  221,  362,    6, 1904, 2172, 2713,  637, 1162,  607, 1014,
#         1664, 2598, 2749,  408, 1750,  898,   85, 1040,  807,  701, 2604,
#         1708, 1163,  649, 1050, 1928,  981, 2352, 1902, 2731,  582,  467,
#         2015, 2024, 2286, 2659,  184, 1837,  966]))

# %%
np.linalg.norm(pca_reduced[f] - pca_reduced[s])
# Out:
# 6.2947448629604965

# %%
second_data_point = nn_array[1][first_data_point][0]

# %%
nn_array[0][first_data_point]
# Out:
# array([8.17850358e-05])

# %%
nn_array[1][first_data_point]
# Out:
# array([2861])

# %%
nn_array[1][second_data_point]
# Out:
# array([2175])

# %%
first_data_point
# Out:
# 2175

# %%
second_data_point
# Out:
# 2861
